# %%
import pandas as pd

raw_data = pd.read_csv("Full_Data.csv")

team_form = {}

team_form_list = []

# %%
def add_new_team(team_name):
    team_form[team_name] = 60

# %%
def update_form(home_team_name, away_team_name, result):
    if result == 1:
        team_form[home_team_name] += 2
        team_form[away_team_name] -= 2
    elif result == -1:
        team_form[home_team_name] -= 3
        team_form[away_team_name] += 3
    else:
        team_form[home_team_name] -= 1
        team_form[away_team_name] += 1

# %%
def reset_form():
    team_form.clear()

# %%
def create_form():
    for i in range(3):
        for j in range(380):
            if raw_data.iloc[380 * i + j]['Home_Team'] not in team_form:
                add_new_team(raw_data.iloc[380 * i + j]['Home_Team'])
            if raw_data.iloc[380 * i + j]['Away_Team'] not in team_form:
                add_new_team(raw_data.iloc[380 * i + j]['Away_Team'])
            home_team_form = team_form[raw_data.iloc[380 * i + j]['Home_Team']]
            away_team_form = team_form[raw_data.iloc[380 * i + j]['Away_Team']]
            
            team_form_list.append({'Home_Form': home_team_form, 'Away_Form': away_team_form})
            
            update_form(raw_data.iloc[380 * i + j]['Home_Team'], raw_data.iloc[380 * i + j]['Away_Team'], raw_data.iloc[380 * i + j]['Result'])
#             print(str(380 * i + j) + " " + row['Home_Team'] + " " + str(team_form[row['Home_Team']]) + " " + row['Away_Team'] + " " + str(team_form[row['Away_Team']]))
        reset_form()

# %%
create_form()

team_form_df = pd.DataFrame(team_form_list, columns=['Home_Form', 'Away_Form'])

raw_data= raw_data.join(team_form_df)

raw_data
# Out:
#       Unnamed: 0  Away_Att  Away_Def  Away_Mid             Away_Team  FTAG  \
# 0              0      73.5     74.00     74.00        Crystal Palace     1
# 1              1      80.5     78.00     79.25               Everton     2
# 2              2      79.5     75.40     75.25               Swansea     2
# 3              3      76.0     74.40     76.00                  Hull     1
# 4              4      77.0     75.60     75.00           Aston Villa     1
# 5              5      78.5     74.20     75.75            Sunderland     2
# 6              6      80.5     80.60     80.00             Tottenham     1
# 7              7      76.5     75.40     77.75           Southampton     1
# 8              8      84.5     82.00     85.00       Manchester City     2
# 9              9      83.0     82.60     84.25               Chelsea     3
# 10            10      75.0     76.60     75.50             Newcastle     0
# 11            11      68.0     73.20     72.00             Leicester     0
# 12            12      74.0     73.20     77.25       West Ham United     3
# 13            13      82.5     80.40     82.00               Arsenal     2
# 14            14      77.0     75.60     76.25  West Bromwich Albion     0
# 15            15      70.0     71.00     70.25               Burnley     0
# 16            16      77.5     76.40     75.75                 Stoke     1
# 17            17      88.0     79.80     83.75     Manchester United     1
# 18            18      75.5     75.80     77.50   Queens Park Rangers     0
# 19            19      82.5     80.40     80.50             Liverpool     1
# 20            20      88.0     79.80     83.75     Manchester United     0
# 21            21      83.0     82.60     84.25               Chelsea     6
# 22            22      77.5     76.40     75.75                 Stoke     1
# 23            23      73.5     74.00     74.00        Crystal Palace     3
# 24            24      78.5     74.20     75.75            Sunderland     0
# 25            25      77.0     75.60     76.25  West Bromwich Albion     0
# 26            26      76.5     75.40     77.75           Southampton     3
# 27            27      76.0     74.40     76.00                  Hull     1
# 28            28      82.5     80.40     82.00               Arsenal     1
# 29            29      82.5     80.40     80.50             Liverpool     3
# ...          ...       ...       ...       ...                   ...   ...
# 28       1          3      68.0     73.20     72.00             Leicester
# 29       0          3      80.5     80.60     80.00             Tottenham
# ...    ...        ...       ...       ...       ...                   ...
# 1110     1         36      75.5     75.40     77.50               Swansea
# 1111     2         36      84.0     82.40     82.00               Arsenal
# 1112     0         36      76.0     74.40     81.50             Liverpool
# 1113     3         36      82.0     80.20     84.25               Chelsea
# 1114     0         36      77.5     78.40     76.25           Southampton
# 1115     1         36      79.5     74.00     79.00               Everton
# 1116     0         36      65.5     73.60     76.50  West Bromwich Albion
# 1117     2         36      71.0     72.25     73.50       AFC Bournemouth
# 1118     2         36      85.0     83.00     83.50       Manchester City
# 1119     1         36      77.0     74.40     74.75         Middlesbrough
# 1120     1         37      80.0     77.40     78.25                 Stoke
# 1121     0         37      78.5     73.80     76.25            Sunderland
# 1122     4         37      80.0     78.20     76.75        Crystal Palace
# 1123     2         37      79.5     81.20     80.50             Tottenham
# 1124     0         37      79.0     77.60     80.25       West Ham United
# 1125     4         37      82.0     80.20     84.25               Chelsea
# 1126     2         37      84.0     82.40     82.00               Arsenal
# 1127     3         37      85.0     83.00     83.50       Manchester City
# 1128     0         37      77.5     78.40     76.25           Southampton
# 1129     1         37      79.5     77.40     77.25             Leicester
# 1130     3         38      84.0     82.40     82.00               Arsenal
# 1131     1         38      71.5     72.00     74.75               Burnley
# 1132     5         38      82.0     80.20     84.25               Chelsea
# 1133     1         38      73.0     74.80     76.00                  Hull
# 1134     1         38      79.5     77.40     77.25             Leicester
# 1135     3         38      76.0     74.40     81.50             Liverpool
# 1136     2         38      77.0     82.00     83.75     Manchester United
# 1137     0         38      77.5     78.40     76.25           Southampton
# 1138     2         38      75.5     75.40     77.50               Swansea
# 1139     0         38      77.5     75.60     73.25               Watford
#
#       Result  Home_Form  Away_Form
# 0          1         60         60
# 1          0         60         60
# 2         -1         60         60
# 3         -1         60         60
# 4         -1         60         60
# 5          0         60         60
# 6         -1         60         60
# 7          1         60         60
# 8         -1         60         60
# 9         -1         60         60
# 10         0         63         57
# 11         1         63         59
# 12        -1         58         57
# 13         0         61         62
# 14         0         58         59
# 15         1         63         57
# 16         0         63         57
# 17         0         61         57
# 18         1         63         57
# 19         1         63         62
# 20         0         55         58
# 21        -1         60         65
# 22        -1         65         58
# 23         0         58         55
# 24         1         55         60
# 25         1         65         60
# 26        -1         60         57
# 27         1         62         62
# 28         0         57         63
# 29        -1         65         60
# ...      ...        ...        ...
# 1110       1         30         78
# 1111       1         83         91
# 1112       0         96         52
# 1113       1        115         30
# 1114      -1         53         85
# 1115       1         76         44
# 1116      -1         57        117
# 1117       1         48         43
# 1118       1         93         51
# 1119      -1         28         50
# 1120      -1         47         88
# 1121      -1         15         32
# 1122       1         38         32
# 1123       1        109         89
# 1124      -1         48         95
# 1125       1        120         42
# 1126       1         91         12
# 1127       1         95         54
# 1128       0         53         87
# 1129      -1         49        111
# 1130       1         93         78
# 1131      -1         41         45
# 1132       1        122         10
# 1133      -1         30        114
# 1134       0         46         50
# 1135       1         98         25
# 1136       1         88         40
# 1137      -1         52         44
# 1138       1         35         52
# 1139      -1         40         97
#
# [1140 rows x 15 columns]
